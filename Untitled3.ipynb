# %%
import pandas as pd
import scipy.cluster.hierarchy as sch

# %%
data=pd.read_csv("~/Documents/iaprojet/IA_project/data.txt", sep="\t")
dat=data.drop(columns=["Country Code","Series Code","Country Name"])
data
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                          Afghanistan          AFG
# ...                                                ...          ...
# 3458                                               NaN          NaN
# 3459                                               NaN          NaN
# 3460                                               NaN          NaN
# 3461  Data from database: World Development Indicators          NaN
# 3462                          Last Updated: 12/22/2022          NaN
#
#                                             Series Name           Series Code  \
# ...

# %%
d=data["2016 [YR2016]"]
l=[]
i=0
while i<len(d):
    j=d.to_list()[i:i+13]
    l.append(j)
    i+=13

q=pd.DataFrame(l)

# %%
da=pd.pivot_table(data,values="2016 [YR2016]",columns="Country Name",index="Series Name")
da
# Out:
# /tmp/ipykernel_13259/2503846464.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   da=pd.pivot_table(data,values="2016 [YR2016]",columns="Country Name",index="Series Name")
# Empty DataFrame
# Columns: []
# ...

# %%
Z = sch.linkage(q, method='complete', metric='euclidean')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 Z = sch.linkage(q, method='complete', metric='euclidean')
#
# File /opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py:1046, in linkage(y, method, metric, optimal_ordering)
#    1043 if method not in _LINKAGE_METHODS:
#    1044     raise ValueError("Invalid method: {0}".format(method))
# -> 1046 y = _convert_to_double(np.asarray(y, order='c'))
#    1048 if y.ndim == 1:
#    1049     distance.is_valid_y(y, throw=True, name='y')
#
# File /opt/anaconda3/lib/python3.9/site-packages/scipy/cluster/hierarchy.py:1572, in _convert_to_double(X)
#    1570 def _convert_to_double(X):
#    1571     if X.dtype != np.double:
# -> 1572         X = X.astype(np.double)
#    1573     if not X.flags.contiguous:
#    1574         X = X.copy()
#
# ...
