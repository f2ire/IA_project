# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.cluster.hierarchy as sch
import data_managment as dm
import matplotlib.pyplot as plt
from sklearn.impute import KNNImputer
from sklearn.cluster import KMeans

# %%
data=pd.read_csv("~/Bureau/4BIM S1/IA/projet/data.txt", sep="\t")
dat=data.drop(columns=["Country Code","Series Code","Country Name"])
data
# Out:
#                                           Country Name Country Code  \
# 0                                          Afghanistan          AFG
# 1                                          Afghanistan          AFG
# 2                                          Afghanistan          AFG
# 3                                          Afghanistan          AFG
# 4                                          Afghanistan          AFG
# ...                                                ...          ...
# 2821                                               NaN          NaN
# 2822                                               NaN          NaN
# 2823                                               NaN          NaN
# 2824  Data from database: World Development Indicators          NaN
# 2825                          Last Updated: 12/22/2022          NaN
#
#                                             Series Name           Series Code  \
# ...

# %%
d=data["2016 [YR2016]"]
l=[]
i=0
while i<len(d):
    j=d.to_list()[i:i+13]
    l.append(j)
    i+=13

q=pd.DataFrame(l)
q
# Out:
#         0                 1                     2            3   \
# 0     1000                ..  0.000866608364478627   13.6430225
# 1      100  5.90330982208252      1.15651054126866  0.080385895
# 2     1900                ..       10.028258191437  0.900352486
# 3       ..                ..                     0  0.703887113
# 4       ..                ..                    ..            0
# ..     ...               ...                   ...          ...
# 213     ..  9.22638988494873                     0  0.190395705
# 214    870  22.6338596343994     0.681565886623517  14.20944734
# 215  61000                ..                     0  14.29453323
# 216  44000                ..                     0  25.08279239
# 217    NaN               NaN                   NaN          NaN
#
#                    4          5     6     7                 8     9     10  \
# 0    5300.00019073486    319.029    ..    ..   3.6802510519657     2    ..
# ...

# %%
df = dm.build_adapted_df(data)
df
# Out:
# Country Name                                        Afghanistan      Albania  \
# Series Name
# Adolescents out of school, male (% of male lowe...          NaN     5.903310
# Adults (ages 15+) and children (ages 0-14) newl...  1000.000000   100.000000
# CO2 emissions (kt)                                  5300.000191  4480.000019
# CO2 emissions from gaseous fuel consumption (kt)     319.029000   161.348000
# CPIA transparency, accountability, and corrupti...     2.000000          NaN
# Child employment in manufacturing (% of economi...          NaN          NaN
# Child employment in manufacturing, female (% of...          NaN          NaN
# Child employment in manufacturing, male (% of m...          NaN          NaN
# Military expenditure (% of general government e...     3.680251     3.787234
# Oil rents (% of GDP)                                   0.000867     1.156511
# People practicing open defecation (% of populat...    13.643023     0.080386
#
# ...

# %%
imputer = KNNImputer(missing_values=np.nan)
imputed_DF = pd.DataFrame(imputer.fit_transform(df))
imputed_DF.columns = df.columns
imputed_DF.index = df.index
imputed_DF
# Out:
# Country Name                                        Afghanistan      Albania  \
# Series Name
# Adolescents out of school, male (% of male lowe...   203.864828     5.903310
# Adults (ages 15+) and children (ages 0-14) newl...  1000.000000   100.000000
# CO2 emissions (kt)                                  5300.000191  4480.000019
# CO2 emissions from gaseous fuel consumption (kt)     319.029000   161.348000
# CPIA transparency, accountability, and corrupti...     2.000000    34.455088
# Child employment in manufacturing (% of economi...   267.270628    22.185488
# Child employment in manufacturing, female (% of...   267.270628    22.185488
# Child employment in manufacturing, male (% of m...   267.270628    22.185488
# Military expenditure (% of general government e...     3.680251     3.787234
# Oil rents (% of GDP)                                   0.000867     1.156511
# People practicing open defecation (% of populat...    13.643023     0.080386
#
# ...

# %%
Z = sch.linkage(imputed_DF, method='complete', metric='euclidean')
#kmEngine = KMeans(n_clusters=8,init="k-means++", n_init=10, max_iter=300,tol=0.0001, random_state=200)
#kmeans=kmEngine.fit(q)
fig = plt.figure(figsize=(20, 40))
dendro = sch.dendrogram(Z, orientation='left', leaf_rotation=0, leaf_font_size=15)

# %%
sns.pairplot(imputed_DF,hue="Country Name")
